# %%
import pandas as pd
import datetime




food={'Prices':['','R2','R6','R7','R6','','','R4','R13','R10','R5','','','R6','R8','R3','R5'],'Order':['Drinks','coca_cola','pine_twist','pepsi','sprite','','Meal','chicken_source','stew','burger','bacon','','Fruits','apple','orange','berry','cherry']}
menu=pd.DataFrame(food)
t=datetime.datetime.now()

# %%
i=0
W=[]
X=[]
P=[]
res=[]

t.year
t.month
t.day
t.hour
t.minute
T=[]
print('Welcome ,please check the menu below and make your Order :  ')
print('')
print('')
print(menu)
while i<4:
    q=input('would you like to order a drink? yes or no :  ')
    w=input('would you like to order a meal? yes or no :  ')
    c=input('would you like to order a fruit? yes or no : ')
    #v=input('Which drink ? : ')
    #h=input('Which meal ? :')
    #s=input('Which fruit ? :')
    if q=='yes':
        v=input('Which drink ? : ')
    else:
            v='NaN'
    if w=='yes':
        h=input('Which meal ? :')
    else:
         h='NaN'
        
    if c=='yes':
        s=input('Which fruit ? :')
    else:
        s='NaN'
        
 #if statements

#for drinks

    if v=='coca_cola':
        r1=2
    if v=='pine_twist':
        r1=6
    if v=='pepsi':
        r1=7
    if v=='sprite':
        r1=6
    if v=='NaN':
        r1=0
        
 #for meals
    if h=='chicken_source':
        r2=4
    if h=='stew':
        r2=13
    if h=='burger':
        r2=10
    if h=='bacon':
        r2=5
    if h=='NaN':
        r2=0
 # for fruits
    if s=='apple':
        r3=6
    if s=='orange':
        r3=8
    if s=='berry':
        r3=3
    if s=='cherry':
        r3=5
    if s=='NaN':
        r3=0
    r=r1+r2+r3
    print('your total bill is : R'+ str(r))
    print(" ")
    print(" ")
        
    
    
     
    S=input("would you like to proceed ,yes or no? ")
    if S=='yes' :
        
        t= str(t.year)+'/'+str(t.month)+'/'+str(t.day)+' '+str(t.hour)+':'+str(t.minute)
        Details ={'Time':T+[t],'Drinks':W+[v],'Meal':X+[h],'Fruit':P+[s],'Sale':res+[r]}
        W=W+[v]
        X=X+[h]
        P=P+[s]
        res=res+[r]
        T= T+[t]
    
    
        
        i=i+1
    else:
        print("Thank you very much for your visit,hope to see you next")

print("  ")
print("  ")
print("  ")        
print(pd.DataFrame(Details))
# Out:
# Welcome ,please check the menu below and make your Order :
#
#
#    Prices           Order
# 0                  Drinks
# 1      R2       coca_cola
# 2      R6      pine_twist
# 3      R7           pepsi
# 4      R6          sprite
# 5
# 6                    Meal
# 7      R4  chicken_source
# 8     R13            stew
# 9     R10          burger
# 10     R5           bacon
# 11
# 12                 Fruits
# 13     R6           apple
# 14     R8          orange
# 15     R3           berry
# 16     R5          cherry
